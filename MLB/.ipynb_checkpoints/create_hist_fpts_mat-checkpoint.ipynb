# %%
# TODO: set covariance to 0 if less than played in less than 10% of games

# %%
import pandas as pd
import os
os.chdir("/Users/alandu/Documents/DFS/")
# from datetime import date, timedelta
import datetime
from pathlib import Path
import numpy as np

# %% [markdown]
# Functions

# %%
def dateRange(start, end, delta):
    dates = []
    curr = start
    while curr < end:
        dates.append(curr)
        curr += delta
    dates = list(dates)
#     output = [date.strftime('%Y-%m-%d') for date in dates]
    return dates

# %% [markdown]
# Create first/base case hist_fpts_mat_update matrix (only need to run once at beginning of season)

# %%
# # first date
# date = "2017-04-02"

# results_mat = pd.read_csv("MLB/data_warehouse/" + date + "/player_results.csv")
# results_mat['Name_Team'] = results_mat['Player'] + "_" + results_mat['Team']
# results_mat = results_mat[['Name_Team', 'Actual Score']]
# results_mat.rename(columns={'Actual Score':date}, inplace = True)
# results_mat

# results_mat.to_csv("MLB/data_warehouse/" + "2017-04-03" + "/hist_fpts_mat_update.csv", index=False, na_rep="NA")

# %% [markdown]
# Create hist_fpts_mat_update for rest of season

# %%
# this code could be cleaned up. got messy because missing some date folders due to missing data / all star break

# rest of dates
date_list = dateRange(datetime.date(2017, 4, 4), datetime.date(2017, 8, 15), datetime.timedelta(days=1))

for date in date_list:
    file_path_date = Path("MLB/data_warehouse/" + date.strftime('%Y-%m-%d'))
    if file_path_date.exists():
        date_tm1 = date - datetime.timedelta(days=1)
        
        # read in hist_fpts_mat_update from date t-1
        file_path_hist = Path("MLB/data_warehouse/" + date_tm1.strftime('%Y-%m-%d') + "/hist_fpts_mat_update.csv")
        if file_path_hist.exists():
            hist_fpts_mat = pd.read_csv(str(file_path_hist))
        else:
            # fill in dates where folder is missing
            temp_date = date_tm1 - datetime.timedelta(days=1)
            file_path_hist = Path("MLB/data_warehouse/" + temp_date.strftime('%Y-%m-%d') + "/hist_fpts_mat_update.csv")
            num_missing = 1
            while (file_path_hist.exists() == False):
                temp_date = temp_date - datetime.timedelta(days=1)
                file_path_hist = Path("MLB/data_warehouse/" + temp_date.strftime('%Y-%m-%d') + "/hist_fpts_mat_update.csv")
                num_missing += 1
            hist_fpts_mat = pd.read_csv(str(file_path_hist))
            print("date(s) missing after " + date.strftime('%Y-%m-%d'))
            for i in range(0,num_missing):
                new_column = temp_date + datetime.timedelta(days=i+1)
                
                # add missing date
                new_column_m1 = new_column - datetime.timedelta(days=1)
#                 print(new_column_m1.strftime('%Y-%m-%d'))
                file_path_results = Path("MLB/data_warehouse/" + new_column_m1.strftime('%Y-%m-%d') + "/player_results.csv")
                if file_path_results.exists():
                    results_mat = pd.read_csv(str(file_path_results))
                    results_mat['Name_Team'] = results_mat['Player'] + "_" + results_mat['Team']
                    hist_fpts_mat = hist_fpts_mat.merge(results_mat[['Name_Team', 'Actual Score']], on="Name_Team", how='outer')
                    hist_fpts_mat.rename(columns={'Actual Score':new_column_m1.strftime('%Y-%m-%d')}, inplace = True)
                elif Path("MLB/data_warehouse/" + new_column_m1.strftime('%Y-%m-%d')).exists():
                    hist_fpts_mat[new_column_m1.strftime('%Y-%m-%d')] = float('NaN')
                
                # add previous dates NA
                hist_fpts_mat[new_column.strftime('%Y-%m-%d')] = float('NaN')
        
        # add fpts for date t
        file_path_results = Path("MLB/data_warehouse/" + date_tm1.strftime('%Y-%m-%d') + "/player_results.csv")
        if file_path_results.exists():
            results_mat = pd.read_csv(str(file_path_results))
            results_mat['Name_Team'] = results_mat['Player'] + "_" + results_mat['Team']

            new_hist_fpts_mat = hist_fpts_mat.merge(results_mat[['Name_Team', 'Actual Score']], on="Name_Team", how='outer')
            new_hist_fpts_mat.rename(columns={'Actual Score':date_tm1.strftime('%Y-%m-%d')}, inplace = True)
        else:
            new_hist_fpts_mat = hist_fpts_mat
            new_hist_fpts_mat[date_tm1.strftime('%Y-%m-%d')] = float('NaN')
        
        # write to file
        new_hist_fpts_mat.to_csv(str(file_path_date) + "/hist_fpts_mat_update.csv", index=False, na_rep="NA")
# Out:
# date missing after 2017-07-10
# date missing after 2017-07-14
# date missing after 2017-07-17
# date missing after 2017-08-09

# %% [markdown]
# Create full covariance matrix for entire season

# %%
date_list = dateRange(datetime.date(2017, 4, 4), datetime.date(2017, 8, 15), datetime.timedelta(days=1))
for date in date_list:
    # create covariance matrix
    file_path_hist = Path("MLB/data_warehouse/" + date.strftime('%Y-%m-%d') + "/hist_fpts_mat_update.csv")
    if file_path_hist.exists():
        hist_fpts_mat_update = pd.read_csv(str(file_path_hist), header=None)
        hist_fpts_mat_update = hist_fpts_mat_update[1:] # remove first row (header)

        player_team_vec = hist_fpts_mat_update[0]
        player_team_vec = player_team_vec.reset_index(drop=True)

        hist_fpts_mat_update = hist_fpts_mat_update.drop(0, 1) # remove first column (names)
        hist_fpts_mat_update = hist_fpts_mat_update.astype(float)
        cov_mat_masked = np.ma.array(hist_fpts_mat_update, mask=np.isnan(hist_fpts_mat_update))
        cov_mat = np.ma.cov(cov_mat_masked, allow_masked=True)
        cov_mat = np.ma.getdata(cov_mat)
        
        # get list of team names in order
        column_teams = []
        for player_team in player_team_vec:
            column_teams.append(player_team.split('_')[1])

        # set covariance to 0 if not on same team
        for ind_row, player_team in enumerate(player_team_vec):
            row_team = player_team_vec[ind_row].split('_')[1]
            for ind_col, column_team in enumerate(column_teams):
                if row_team != column_team:
                    cov_mat[ind_row, ind_col] = 0.0
                    
        # TODO: set to 0 if less than played in less than 5% of games
                    
        # convert to pandas df to add column names
        cov_mat = pd.DataFrame(cov_mat)
        cov_mat.columns = player_team_vec
        
        # write to file
        cov_mat.to_csv("MLB/data_warehouse/" + date.strftime('%Y-%m-%d') + "/covariance_mat_update.csv", index=False, na_rep="NA")
        print(date.strftime('%Y-%m-%d') + " completed")

# %% [markdown]
# Subset covariance matrix for each contest

# %%
date_list = dateRange(datetime.date(2017, 5, 1), datetime.date(2017, 6, 30), datetime.timedelta(days=1))

for date in date_list:
    # read in contests.csv and subset by date
    contests_file = pd.read_csv("MLB/data_warehouse/contests.csv")
    contests_file = contests_file[(contests_file['Contest_Date'] == date.strftime('%Y-%m-%d'))]
    contests_file = contests_file.reset_index()
    
    for i in range(0, len(contests_file)):
        file_path_hist = Path("MLB/data_warehouse/" + date.strftime('%Y-%m-%d') + "/hist_fpts_mat_update.csv")
        file_path_date = Path("MLB/data_warehouse/" + date.strftime('%Y-%m-%d'))
        if file_path_hist.exists():
            # read in hist_fpts_mat_update (don't actually need this but used for convenience of column names)
            hist_fpts_mat_update = pd.read_csv(str(file_path_hist), header=None)

            # read in hitters.csv
            contest_name = contests_file['Entry_Fee'][i] + "entry_" + contests_file['Contest_Name'][i].replace(" ", "")
            file_path_hitters =  Path(str(file_path_date) + "/" + contest_name + "/hitters.csv")
            if file_path_hitters.exists():
                hitters_df = pd.read_csv(str(file_path_date) + "/" + contest_name + "/hitters.csv")

                # read in covariance_mat_update and update it
                covariance_mat_update = pd.read_csv(str(file_path_date) + "/covariance_mat_update.csv")

                # find indicies of each player in hitters_df in hist_fpts_mat_update
                hitters_name_team = hitters_df['Name'] + "_" + hitters_df['teamAbbrev']
                inds_match = []
                for name_team in hitters_name_team:
                    inds_match.append(hist_fpts_mat_update[hist_fpts_mat_update[0] == name_team].index.tolist())

                # find indicies of missing players (will be 0's in covariance matrix)
                inds_missing = []
                for i, ind in enumerate(inds_match):
                    if (len(ind) == 0):
                        inds_missing.append(i)

                # append 0's to covariance matrix
                inds_added = []
                for i in range(0,len(inds_missing)):
                    covariance_mat_update.loc[len(covariance_mat_update)] = 0
                    covariance_mat_update[len(covariance_mat_update)] = pd.Series(np.zeros(len(covariance_mat_update)), index=covariance_mat_update.index)
                    inds_added.append(len(covariance_mat_update)-1)

                # fill in inds where no match
                for i, ind in enumerate(inds_missing):
                    inds_match[ind] = [inds_added[i]]

                # unlist for numpy function
                inds_match = sum(inds_match, [])

                # update covariance matrix
                covariance_mat_update = np.array(covariance_mat_update)
                covariance_mat_update = covariance_mat_update[np.ix_(inds_match,inds_match)] # subset nxn matrix into mxm
                covariance_mat_update = pd.DataFrame(covariance_mat_update)
                covariance_mat_update.columns = hitters_name_team # set column names

                # write to file
                covariance_mat_update.to_csv("MLB/data_warehouse/" + date.strftime('%Y-%m-%d') + "/" + contest_name + "/covariance_mat_update.csv", index=False, na_rep="NA")

                # print
                print(date.strftime('%Y-%m-%d') + " " + contest_name + " completed")
# Out:
# 2017-05-01 $33.00entry_MLB$325KFastball[$50Kto1st] completed
# 2017-05-01 $4.00entry_MLB$175KFour-Seamer[20EntryMax] completed
# 2017-05-01 $333.00entry_MLB$250KSUPERPerfectGame[$50Kto1st] completed
# 2017-05-01 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-01 $5.00entry_MLB$5DoubleUp completed
# 2017-05-01 $5.00entry_MLB$5DoubleUp completed
# 2017-05-01 $1.00entry_MLB$5CincoDeMayoSpecialSUPERSat[200x] completed
# 2017-05-01 $0.25entry_MLB$5CincoDeMayoSpecialSUPERSat[150x] completed
# 2017-05-01 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[30x] completed
# 2017-05-01 $10.00entry_MLB$10DoubleUp completed
# 2017-05-01 $2.00entry_MLB$2DoubleUp completed
# 2017-05-01 $9.00entry_MLB$4KSlider completed
# 2017-05-01 $5.00entry_MLB$5KKnuckleball completed
# 2017-05-01 $2.00entry_MLB$2KFlare completed
# 2017-05-01 $2.00entry_MLB$4KFlare completed
# 2017-05-01 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-01 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-01 $3.00entry_MLB$7KMoonshot(Turbo) completed
# 2017-05-01 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-01 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-01 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-01 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-01 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-01 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-01 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-02 $8.00entry_MLB$350KCrazy8's completed
# 2017-05-02 $33.00entry_MLB$175KFastball completed
# 2017-05-02 $333.00entry_MLB$200KPerfectGame completed
# 2017-05-02 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-02 $0.25entry_MLB$5CincoDeMayoSpecialSUPERSat[200x] completed
# 2017-05-02 $1.00entry_MLB$5CincoDeMayoSpecialSUPERSat[250x] completed
# 2017-05-02 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-02 $5.00entry_MLB$5DoubleUp completed
# 2017-05-02 $5.00entry_MLB$5DoubleUp completed
# 2017-05-02 $10.00entry_MLB$10DoubleUp completed
# 2017-05-02 $2.00entry_MLB$2DoubleUp completed
# 2017-05-02 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-02 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[30x] completed
# 2017-05-02 $0.25entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[20x] completed
# 2017-05-02 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-02 $2.00entry_MLB$5KFlare completed
# 2017-05-02 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-02 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-02 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-02 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-02 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-02 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-02 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-02 $8.00entry_MLB$35KCrazy8's(Night) completed
# 2017-05-02 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-02 $4.00entry_MLB$10KFour-Seamer(Night) completed
# 2017-05-02 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-02 $1.00entry_MLB$3KSoloShot(Night) completed
# 2017-05-02 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-03 $8.00entry_MLB$350KCrazy8's[$50Kto1st] completed
# 2017-05-03 $33.00entry_MLB$215KFastball completed
# 2017-05-03 $333.00entry_MLB$225KPerfectGame completed
# 2017-05-03 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-03 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-03 $5.00entry_MLB$5DoubleUp completed
# 2017-05-03 $5.00entry_MLB$5DoubleUp completed
# 2017-05-03 $1.00entry_MLB$5CincoDeMayoSpecialSUPERSat[250x] completed
# 2017-05-03 $0.25entry_MLB$5CincoDeMayoSpecialSUPERSat[200x] completed
# 2017-05-03 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[30x] completed
# 2017-05-03 $10.00entry_MLB$10DoubleUp completed
# 2017-05-03 $2.00entry_MLB$2DoubleUp completed
# 2017-05-03 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-03 $2.00entry_MLB$5KFlare completed
# 2017-05-03 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-03 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-03 $8.00entry_MLB$6KCrazy8's(Turbo) completed
# 2017-05-03 $4.00entry_MLB$2KFour-Seamer(Turbo) completed
# 2017-05-03 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-03 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-03 $4.00entry_MLB$35KFour-Seamer(Night) completed
# 2017-05-03 $8.00entry_MLB$6KCrazy8's(Turbo) completed
# 2017-05-03 $33.00entry_MLB$20KFastball(Night) completed
# 2017-05-03 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-03 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-03 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-03 $1.00entry_MLB$3KSoloShot(Night) completed
# 2017-05-03 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-04 $33.00entry_MLB$150KFastball completed
# 2017-05-04 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-04 $33.00entry_MLB$100KFastball(Early) completed
# 2017-05-04 $4.00entry_MLB$50KFour-Seamer[20EntryMax](Early) completed
# 2017-05-04 $5.00entry_MLB$5DoubleUp completed
# 2017-05-04 $5.00entry_MLB$5DoubleUp completed
# 2017-05-04 $3.00entry_MLB$4KMoonshot(AllDay) completed
# 2017-05-04 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-04 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-04 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-04 $0.25entry_MLB$5CincoDeMayoSpecialSUPERSat[150x](Early) completed
# 2017-05-04 $1.00entry_MLB$5CincoDeMayoSpecialSUPERSat[150x](Early) completed
# 2017-05-04 $0.25entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x](Early) completed
# 2017-05-04 $2.00entry_MLB$2.5KFlare(Early) completed
# 2017-05-04 $1.00entry_MLB$5KSoloShot(Early) completed
# 2017-05-04 $0.25entry_MLB$2.5KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-04 $3.00entry_MLB$6KMoonshot(Afternoon) completed
# 2017-05-04 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Afternoon) completed
# 2017-05-04 $1.00entry_MLB$1KSoloShot(Afternoon) completed
# 2017-05-04 $1.00entry_MLB$5CincoDeMayoSpecialSUPERSat[350x] completed
# 2017-05-04 $0.25entry_MLB$5CincoDeMayoSpecialSUPERSat[250x] completed
# 2017-05-04 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x] completed
# 2017-05-04 $10.00entry_MLB$10DoubleUp completed
# 2017-05-04 $2.00entry_MLB$2DoubleUp completed
# 2017-05-04 $5.00entry_MLB$2.5KKnuckleball completed
# 2017-05-04 $2.00entry_MLB$3KFlare completed
# 2017-05-04 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-04 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-05 $5.00entry_MLB$300KCincoDeMayoSpecial[$50Kto1st] completed
# 2017-05-05 $33.00entry_MLB$200KFastball completed
# 2017-05-05 $400.00entry_MLB$300KFRIDAYHomeRun[50Kto1st] completed
# 2017-05-05 $4.00entry_MLB$20KFour-Seamer[20EntryMax](Early) completed
# 2017-05-05 $33.00entry_MLB$15KFastball(Early) completed
# 2017-05-05 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-05 $5.00entry_MLB$5DoubleUp completed
# 2017-05-05 $5.00entry_MLB$5DoubleUp completed
# 2017-05-05 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[30x] completed
# 2017-05-05 $10.00entry_MLB$10DoubleUp completed
# 2017-05-05 $2.00entry_MLB$2DoubleUp completed
# 2017-05-05 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-05 $2.00entry_MLB$5KFlare completed
# 2017-05-05 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-05 $0.25entry_MLBSUPERSatellitetoWeekendPGA$125KCrazy8's completed
# 2017-05-05 $1.00entry_MLBSUPERSatellitetoWeekendPGA$125KCrazy8's completed
# 2017-05-05 $0.25entry_MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x] completed
# 2017-05-05 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-05 $1.00entry_MLB$2.5KSoloShot(Early) completed
# 2017-05-05 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-05 $3.00entry_MLB$3KMoonshot(AllDay) completed
# 2017-05-05 $1.00entry_MLB$1KSoloShot(AllDay) completed
# 2017-05-05 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-05 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-05 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-05 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-05 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-05 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-05 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-05 $8.00entry_MLB$30KCrazy8's(Night) completed
# 2017-05-05 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-05 $4.00entry_MLB$10KFour-Seamer(Night) completed
# 2017-05-05 $0.25entry_MLBSUPERSatellitetoWeekendPGA$125KCrazy8's(Night) completed
# 2017-05-05 $1.00entry_MLBSUPERSatellitetoWeekendPGA$125KCrazy8's(Night) completed
# 2017-05-05 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-05 $1.00entry_MLB$3KSoloShot(Night) completed
# 2017-05-05 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-06 $40.00entry_MLB$250KSaturdaySlugfest completed
# 2017-05-06 $4.00entry_MLB$110KFour-Seamer[20EntryMax] completed
# 2017-05-06 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-06 $33.00entry_MLB$50KFastball(Early) completed
# 2017-05-06 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-05-06 $25.00entry_MLB$25DoubleUp completed
# 2017-05-06 $5.00entry_MLB$5DoubleUp completed
# 2017-05-06 $5.00entry_MLB$5DoubleUp completed
# 2017-05-06 $1.00entry_MLB$6SwingForTheFencesSUPERSat[125x] completed
# 2017-05-06 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-06 $10.00entry_MLB$10DoubleUp completed
# 2017-05-06 $2.00entry_MLB$2DoubleUp completed
# 2017-05-06 $1.00entry_MLB$8KSoloShot completed
# 2017-05-06 $5.00entry_MLB$3KKnuckleball completed
# 2017-05-06 $2.00entry_MLB$4KFlare completed
# 2017-05-06 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-06 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-06 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-05-06 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-06 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-06 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-06 $3.00entry_MLB$4KMoonshot(AllDay) completed
# 2017-05-06 $1.00entry_MLB$1KSoloShot(AllDay) completed
# 2017-05-06 $0.25entry_MLB$750QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-06 $3.00entry_MLB$10KMoonshot(Turbo) completed
# 2017-05-06 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-06 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-06 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-06 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-06 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-06 $3.00entry_MLB$12KMoonshot(Night) completed
# 2017-05-06 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-06 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-07 $50.00entry_MLB$300KSundayNiftyFifty completed
# 2017-05-07 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-07 $333.00entry_MLB$140KPerfectGame completed
# 2017-05-07 $6.00entry_LASTSHOT:MLB$800KMEGACrazy8'sSUPERSat[3x] completed
# 2017-05-07 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-07 $5.00entry_MLB$5DoubleUp completed
# 2017-05-07 $5.00entry_MLB$5DoubleUp completed
# 2017-05-07 $2.00entry_MLB$2DoubleUp completed
# 2017-05-07 $1.00entry_MLB$10KSoloShot completed
# 2017-05-07 $9.00entry_MLB$4KSlider completed
# 2017-05-07 $2.00entry_MLB$3KFlare completed
# 2017-05-07 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-07 $0.25entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[20x] completed
# 2017-05-07 $0.25entry_MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x] completed
# 2017-05-07 $1.00entry_MLB$1.5KSoloShot(AllDay) completed
# 2017-05-07 $3.00entry_MLB$6KMoonshot(AllDay) completed
# 2017-05-07 $0.25entry_MLB$750QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-07 $3.00entry_MLB$9KMoonshot(Turbo) completed
# 2017-05-07 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-07 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-07 $4.00entry_MLB$35KFour-Seamer(Afternoon) completed
# 2017-05-07 $33.00entry_MLB$25KFastball(Afternoon) completed
# 2017-05-07 $2.00entry_MLB$1KFlare(Afternoon) completed
# 2017-05-07 $1.00entry_MLB$2.5KSoloShot(Afternoon) completed
# 2017-05-07 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Afternoon) completed
# 2017-05-07 $2.00entry_MLB$2DoubleUp(Afternoon) completed
# 2017-05-07 $0.25entry_MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x](Afternoon) completed
# 2017-05-07 $3.00entry_MLB$7KMoonshot(Turbo) completed
# 2017-05-07 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-07 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-07 $3.00entry_MLB$4KMoonshot(Late) completed
# 2017-05-07 $1.00entry_MLB$1KSoloShot(Late) completed
# 2017-05-07 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Late) completed
# 2017-05-08 $888.00entry_MLB$800KMEGACrazy8's[$150Kto1st] completed
# 2017-05-08 $88.00entry_MLB$250KMediumCrazy8's completed
# 2017-05-08 $8.00entry_MLB$175KCrazy8's completed
# 2017-05-08 $5.00entry_FansChoice:MLB$30KSurvivor[Top4,000Advance!] completed
# 2017-05-08 $4.00entry_MLB$50KFour-Seamer[20EntryMax] completed
# 2017-05-08 $33.00entry_MLB$30KFastball completed
# 2017-05-08 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-08 $5.00entry_MLB$5DoubleUp completed
# 2017-05-08 $5.00entry_MLB$5DoubleUp completed
# 2017-05-08 $1.00entry_MLB$6SwingForTheFencesSUPERSat[250x] completed
# 2017-05-08 $0.25entry_MLB$6SwingForTheFencesSUPERSat[200x] completed
# 2017-05-08 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSat[30x] completed
# 2017-05-08 $0.25entry_MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x] completed
# 2017-05-08 $10.00entry_MLB$10DoubleUp completed
# 2017-05-08 $2.00entry_MLB$2DoubleUp completed
# 2017-05-08 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-08 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-08 $2.00entry_MLB$5KFlare completed
# 2017-05-08 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-08 $3.00entry_MLB$12KMoonshot(Night) completed
# 2017-05-08 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-08 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-08 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-08 $8.00entry_MLB$20KCrazy8's(LateNight) completed
# 2017-05-08 $4.00entry_MLB$10KFour-Seamer(LateNight) completed
# 2017-05-08 $2.00entry_MLB$1KFlare(LateNight) completed
# 2017-05-08 $1.00entry_MLB$2KSoloShot(LateNight) completed
# 2017-05-08 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-08 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x](LateNight) completed
# 2017-05-09 $888.00entry_MLB$500KMEGA$8'sEncore[$100Kto1st] completed
# 2017-05-09 $55.00entry_MLB$325KFullCount completed
# 2017-05-09 $8.00entry_MLB$200KRallyCap completed
# 2017-05-09 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-09 $0.25entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-09 $1.00entry_MLB$6SwingForTheFencesSUPERSat[400x] completed
# 2017-05-09 $5.00entry_MLB$5DoubleUp completed
# 2017-05-09 $5.00entry_MLB$5DoubleUp completed
# 2017-05-09 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-09 $1.00entry_MLB$15KSoloShot completed
# 2017-05-09 $10.00entry_MLB$10DoubleUp completed
# 2017-05-09 $2.00entry_MLB$2DoubleUp completed
# 2017-05-09 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-09 $2.00entry_MLB$5KFlare completed
# 2017-05-09 $0.25entry_MLB$6KQuarterArcade completed
# 2017-05-09 $0.25entry_2DAYS:MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x] completed
# 2017-05-09 $3.00entry_MLB$3KMoonshot(Early) completed
# 2017-05-09 $1.00entry_MLB$500SoloShot(Early) completed
# 2017-05-09 $1.00entry_MLB$1KSoloShot(Early) completed
# 2017-05-09 $0.25entry_MLB$250QuarterArcade[Just$0.25!](Early) completed
# 2017-05-09 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Early) completed
# 2017-05-09 $4.00entry_MLB$2.5KFour-Seamer(Turbo) completed
# 2017-05-09 $1.00entry_MLB$500SoloShot(Turbo) completed
# 2017-05-09 $3.00entry_MLB$7KMoonshot(Turbo) completed
# 2017-05-09 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-09 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-09 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-09 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-09 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-09 $4.00entry_MLB$20KFour-Seamer(Night) completed
# 2017-05-09 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-09 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-09 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-05-09 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-09 $3.00entry_MLB$10KMoonshot(LateNight) completed
# 2017-05-09 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-09 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-10 $33.00entry_MLB$100KFastball(Early) completed
# 2017-05-10 $4.00entry_MLB$60KFour-Seamer[20EntryMax](Early) completed
# 2017-05-10 $55.00entry_MLB$250KFullCount completed
# 2017-05-10 $8.00entry_MLB$150KRallyCap completed
# 2017-05-10 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-10 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-10 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-10 $3.00entry_MLB$3KMoonshot(AllDay) completed
# 2017-05-10 $1.00entry_MLB$1.5KSoloShot(Early) completed
# 2017-05-10 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-10 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-10 $3.00entry_MLB$5KMoonshot(Afternoon) completed
# 2017-05-10 $1.00entry_MLB$1KSoloShot(Afternoon) completed
# 2017-05-10 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Afternoon) completed
# 2017-05-10 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-10 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-05-10 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-10 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-10 $5.00entry_MLB$5DoubleUp completed
# 2017-05-10 $5.00entry_MLB$5DoubleUp completed
# 2017-05-10 $10.00entry_MLB$10DoubleUp completed
# 2017-05-10 $2.00entry_MLB$2DoubleUp completed
# 2017-05-10 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-10 $0.25entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-10 $0.25entry_LASTSHOT:MLBSUPERSatellitetoPGA$600KDrivetheGreen[25x] completed
# 2017-05-10 $2.00entry_MLB$4KFlare completed
# 2017-05-10 $1.00entry_MLB$10KSoloShot completed
# 2017-05-10 $0.25entry_MLB$5KQuarterArcade completed
# 2017-05-10 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-10 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-10 $3.00entry_MLB$10KMoonshot(Turbo) completed
# 2017-05-10 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-10 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-10 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-10 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-05-10 $4.00entry_MLB$25KFour-Seamer(Night) completed
# 2017-05-11 $33.00entry_MLB$40KFastball(Early) completed
# 2017-05-11 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-05-11 $33.00entry_MLB$250KFastball[$25Kto1st] completed
# 2017-05-11 $4.00entry_MLB$140KFour-Seamer[20EntryMax] completed
# 2017-05-11 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-11 $1.00entry_MLB$5KSoloShot(Early) completed
# 2017-05-11 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-05-11 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-11 $0.25entry_MLB$2KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-11 $3.00entry_MLB$2.5KMoonshot(AllDay) completed
# 2017-05-11 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-11 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-11 $25.00entry_MLB$25DoubleUp completed
# 2017-05-11 $5.00entry_MLB$5DoubleUp completed
# 2017-05-11 $5.00entry_MLB$5DoubleUp completed
# 2017-05-11 $10.00entry_MLB$10DoubleUp completed
# 2017-05-11 $2.00entry_MLB$2DoubleUp completed
# 2017-05-11 $5.00entry_MLB$2.5KKnuckleball completed
# 2017-05-11 $2.00entry_MLB$4KFlare completed
# 2017-05-11 $1.00entry_MLB$8KSoloShot completed
# 2017-05-11 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-11 $1.00entry_MLB$6SwingForTheFencesSUPERSat[200x] completed
# 2017-05-11 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-11 $3.00entry_MLB$7KMoonshot(Turbo) completed
# 2017-05-11 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-11 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-11 $3.00entry_MLB$6KMoonshot(Turbo) completed
# 2017-05-11 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-11 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-11 $4.00entry_MLB$25KFour-Seamer(Night) completed
# 2017-05-11 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-11 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-11 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-05-11 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-11 $3.00entry_MLB$10KMoonshot(LateNight) completed
# 2017-05-11 $1.00entry_MLB$1.5KSoloShot(LateNight) completed
# 2017-05-11 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-12 $400.00entry_MLB$400KFRIDAYHomeRun[$100Kto1st] completed
# 2017-05-12 $55.00entry_MLB$300KFullCount completed
# 2017-05-12 $8.00entry_MLB$150KRallyCap completed
# 2017-05-12 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-12 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-12 $5.00entry_MLB$5DoubleUp completed
# 2017-05-12 $5.00entry_MLB$5DoubleUp completed
# 2017-05-12 $1.00entry_MLB$6SwingForTheFencesSUPERSat[400x] completed
# 2017-05-12 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-12 $10.00entry_MLB$10DoubleUp completed
# 2017-05-12 $2.00entry_MLB$2DoubleUp completed
# 2017-05-12 $0.25entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-12 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-12 $2.00entry_MLB$4KFlare completed
# 2017-05-12 $0.25entry_MLB$5KQuarterArcade completed
# 2017-05-12 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-12 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-12 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-12 $3.00entry_MLB$4KMoonshot(Turbo) completed
# 2017-05-12 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-05-12 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-12 $4.00entry_MLB$20KFour-Seamer(Night) completed
# 2017-05-12 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-12 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-12 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-05-12 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-12 $4.00entry_MLB$8KFour-Seamer(LateNight) completed
# 2017-05-12 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-12 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-13 $40.00entry_MLB$250KSaturdaySlugfest completed
# 2017-05-13 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-13 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-13 $33.00entry_MLB$110KFastball(Early) completed
# 2017-05-13 $4.00entry_MLB$50KFour-Seamer[20EntryMax](Early) completed
# 2017-05-13 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-13 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-13 $1.00entry_MLB$5KSoloShot(Early) completed
# 2017-05-13 $0.25entry_MLB$2KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-13 $3.00entry_MLB$4KMoonshot(AllDay) completed
# 2017-05-13 $1.00entry_MLB$1KSoloShot(AllDay) completed
# 2017-05-13 $0.25entry_MLB$750QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-13 $5.00entry_MLB$5DoubleUp completed
# 2017-05-13 $25.00entry_MLB$25DoubleUp completed
# 2017-05-13 $1.00entry_MLB$10KSoloShot completed
# 2017-05-13 $10.00entry_MLB$10DoubleUp completed
# 2017-05-13 $2.00entry_MLB$2DoubleUp completed
# 2017-05-13 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-13 $0.25entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-13 $5.00entry_MLB$3KKnuckleball completed
# 2017-05-13 $2.00entry_MLB$4KFlare completed
# 2017-05-13 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-13 $4.00entry_MLB$12KFour-Seamer(Afternoon) completed
# 2017-05-13 $1.00entry_MLB$1KSoloShot(Afternoon) completed
# 2017-05-13 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Afternoon) completed
# 2017-05-13 $4.00entry_MLB$20KFour-Seamer(Night) completed
# 2017-05-13 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-13 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Night) completed
# 2017-05-14 $50.00entry_MLB$300KMother'sDaySpecial completed
# 2017-05-14 $4.00entry_MLB$100KMiniMother'sDaySpecial[20EntryMax] completed
# 2017-05-14 $333.00entry_MLB$140KPerfectGame completed
# 2017-05-14 $25.00entry_MLB$25DoubleUp completed
# 2017-05-14 $5.00entry_MLB$5DoubleUp completed
# 2017-05-14 $5.00entry_MLB$5DoubleUp completed
# 2017-05-14 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-14 $0.25entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-14 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x] completed
# 2017-05-14 $2.00entry_MLB$3KFlare completed
# 2017-05-14 $1.00entry_MLB$10KSoloShot completed
# 2017-05-14 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-14 $3.00entry_MLB$6KMoonshot(AllDay) completed
# 2017-05-14 $1.00entry_MLB$1.5KSoloShot(AllDay) completed
# 2017-05-14 $0.25entry_MLB$750QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-14 $3.00entry_MLB$9KMoonshot(Turbo) completed
# 2017-05-14 $1.00entry_MLB$1.5KSoloShot(Turbo) completed
# 2017-05-14 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-14 $4.00entry_MLB$25KFour-Seamer(Afternoon) completed
# 2017-05-14 $33.00entry_MLB$15KFastball(Afternoon) completed
# 2017-05-14 $2.00entry_MLB$2DoubleUp(Afternoon) completed
# 2017-05-14 $2.00entry_MLB$1KFlare(Afternoon) completed
# 2017-05-14 $1.00entry_MLB$2KSoloShot(Afternoon) completed
# 2017-05-14 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](Afternoon) completed
# 2017-05-14 $3.00entry_MLB$4KMoonshot(Turbo) completed
# 2017-05-14 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-14 $0.25entry_MLB$5KQuarterArcade(Turbo) completed
# 2017-05-14 $3.00entry_MLB$5KMoonshot(Night) completed
# 2017-05-14 $1.00entry_MLB$1KSoloShot(Night) completed
# 2017-05-14 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Night) completed
# 2017-05-15 $33.00entry_MLB$200KFastball[$30Kto1st] completed
# 2017-05-15 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-15 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-15 $25.00entry_MLB$25DoubleUp completed
# 2017-05-15 $5.00entry_MLB$5DoubleUp completed
# 2017-05-15 $4.00entry_MLB$6KFour-Seamer(AllDay) completed
# 2017-05-15 $1.00entry_MLB$1.5KSoloShot(AllDay) completed
# 2017-05-15 $0.25entry_MLB$750QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-15 $10.00entry_MLB$10DoubleUp completed
# 2017-05-15 $2.00entry_MLB$2DoubleUp completed
# 2017-05-15 $1.00entry_MLB$12.5KSoloShot completed
# 2017-05-15 $5.00entry_MLB$4KKnuckleball completed
# 2017-05-15 $2.00entry_MLB$5KFlare completed
# 2017-05-15 $0.25entry_MLB$5KQuarterArcade completed
# 2017-05-15 $1.00entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-15 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-15 $8.00entry_MLB$25KCrazy8's(Night) completed
# 2017-05-15 $33.00entry_MLB$15KFastball(Night) completed
# 2017-05-15 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-15 $2.00entry_MLB$1KFlare(Night) completed
# 2017-05-15 $1.00entry_MLB$2.5KSoloShot(Night) completed
# 2017-05-15 $0.25entry_MLB$1.5KQuarterArcade[Just$0.25!](Night) completed
# 2017-05-15 $4.00entry_MLB$15KFour-Seamer(LateNight) completed
# 2017-05-15 $1.00entry_MLB$2KSoloShot(LateNight) completed
# 2017-05-15 $0.25entry_MLB$1KQuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-16 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-05-16 $33.00entry_MLB$35KFastball(Early) completed
# 2017-05-16 $55.00entry_MLB$75KFullCount completed
# 2017-05-16 $55.00entry_MLB$300KFullCount[$50Kto1st] completed
# 2017-05-16 $444.00entry_MLB$250KGrandSlam completed
# 2017-05-16 $8.00entry_MLB$115KRallyCap completed
# 2017-05-16 $4.00entry_MLB$70KFour-Seamer[20EntryMax] completed
# 2017-05-16 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-05-16 $33.00entry_MLB$35KFastball(Early) completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-16 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-16 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-16 $0.25entry_MLB$2KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-16 $3.00entry_MLB$3KMoonshot(AllDay) completed
# 2017-05-16 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-16 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-16 $1.00entry_MLB$10KSoloShot completed
# 2017-05-16 $10.00entry_MLB$10DoubleUp completed
# 2017-05-16 $2.00entry_MLB$2DoubleUp completed
# 2017-05-16 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-16 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-16 $5.00entry_MLB$2.5KKnuckleball completed
# 2017-05-16 $2.00entry_MLB$4KFlare completed
# 2017-05-16 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-16 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-16 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-05-16 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-16 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-16 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-16 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Night) completed
# 2017-05-16 $4.00entry_MLB$4KFour-Seamer(LateNight) completed
# 2017-05-16 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-16 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-16 $55.00entry_MLB$300KFullCount[$50Kto1st] completed
# 2017-05-16 $444.00entry_MLB$250KGrandSlam completed
# 2017-05-16 $8.00entry_MLB$115KRallyCap completed
# 2017-05-16 $4.00entry_MLB$70KFour-Seamer[20EntryMax] completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-16 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-16 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-05-16 $33.00entry_MLB$35KFastball(Early) completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-16 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $5.00entry_MLB$5DoubleUp completed
# 2017-05-16 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-16 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-16 $0.25entry_MLB$2KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-16 $3.00entry_MLB$3KMoonshot(AllDay) completed
# 2017-05-16 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-16 $0.25entry_MLB$500QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-16 $1.00entry_MLB$10KSoloShot completed
# 2017-05-16 $10.00entry_MLB$10DoubleUp completed
# 2017-05-16 $2.00entry_MLB$2DoubleUp completed
# 2017-05-16 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-16 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-16 $5.00entry_MLB$2.5KKnuckleball completed
# 2017-05-16 $2.00entry_MLB$4KFlare completed
# 2017-05-16 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-16 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-16 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-05-16 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-16 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-16 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-16 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Night) completed
# 2017-05-16 $4.00entry_MLB$4KFour-Seamer(LateNight) completed
# 2017-05-16 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-16 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-17 $55.00entry_MLB$250KFullCount completed
# 2017-05-17 $8.00entry_MLB$150KRallyCap completed
# 2017-05-17 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-17 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-17 $33.00entry_MLB$60KFastball(Early) completed
# 2017-05-17 $4.00entry_MLB$25KFour-Seamer[20EntryMax](Early) completed
# 2017-05-17 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-17 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-05-17 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-17 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-17 $0.25entry_MLB$2KQuarterArcade[Just$0.25!](Early) completed
# 2017-05-17 $3.00entry_MLB$2KMoonshot(AllDay) completed
# 2017-05-17 $1.00entry_MLB$500SoloShot(AllDay) completed
# 2017-05-17 $0.25entry_MLB$400QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-17 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-17 $5.00entry_MLB$5DoubleUp completed
# 2017-05-17 $5.00entry_MLB$5DoubleUp completed
# 2017-05-17 $1.00entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-17 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-17 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x] completed
# 2017-05-17 $10.00entry_MLB$10DoubleUp completed
# 2017-05-17 $2.00entry_MLB$2DoubleUp completed
# 2017-05-17 $2.00entry_MLB$4KFlare completed
# 2017-05-17 $1.00entry_MLB$10KSoloShot completed
# 2017-05-17 $0.25entry_MLB$5KQuarterArcade completed
# 2017-05-17 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-17 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-17 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-17 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-17 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-17 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-17 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-17 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-17 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Night) completed
# 2017-05-18 $33.00entry_MLB$200KFastball completed
# 2017-05-18 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-18 $3.00entry_MLB$3KMoonshot(Turbo) completed
# 2017-05-18 $0.25entry_MLB$250QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-18 $1.00entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-18 $5.00entry_MLB$5DoubleUp completed
# 2017-05-18 $5.00entry_MLB$5DoubleUp completed
# 2017-05-18 $0.25entry_MLB$6SwingForTheFencesSUPERSat[50x] completed
# 2017-05-18 $2.00entry_MLB$2DoubleUp completed
# 2017-05-18 $2.00entry_MLB$3KFlare completed
# 2017-05-18 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-18 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-18 $3.00entry_MLB$7KMoonshot(Night) completed
# 2017-05-18 $1.00entry_MLB$750SoloShot(Night) completed
# 2017-05-18 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Night) completed
# 2017-05-18 $4.00entry_MLB$12KFour-Seamer(LateNight) completed
# 2017-05-18 $1.00entry_MLB$1.5KSoloShot(LateNight) completed
# 2017-05-18 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-18 $33.00entry_MLB$200KFastball completed
# 2017-05-18 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-18 $3.00entry_MLB$3KMoonshot(Turbo) completed
# 2017-05-18 $0.25entry_MLB$250QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-18 $1.00entry_MLB$6SwingForTheFencesSUPERSat[150x] completed
# 2017-05-18 $5.00entry_MLB$5DoubleUp completed
# 2017-05-18 $5.00entry_MLB$5DoubleUp completed
# 2017-05-18 $0.25entry_MLB$6SwingForTheFencesSUPERSat[50x] completed
# 2017-05-18 $2.00entry_MLB$2DoubleUp completed
# 2017-05-18 $2.00entry_MLB$3KFlare completed
# 2017-05-18 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-18 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-18 $3.00entry_MLB$7KMoonshot(Night) completed
# 2017-05-18 $1.00entry_MLB$750SoloShot(Night) completed
# 2017-05-18 $0.25entry_MLB$500QuarterArcade[Just$0.25!](Night) completed
# 2017-05-18 $4.00entry_MLB$12KFour-Seamer(LateNight) completed
# 2017-05-18 $1.00entry_MLB$1.5KSoloShot(LateNight) completed
# 2017-05-18 $0.25entry_MLB$750QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-19 $33.00entry_MLB$300KFastball[$50Kto1st] completed
# 2017-05-19 $555.00entry_MLB$555KWalk-OffHomeRun[$100Kto1st] completed
# 2017-05-19 $8.00entry_MLB$100KRallyCap completed
# 2017-05-19 $4.00entry_MLB$60KFour-Seamer[20EntryMax] completed
# 2017-05-19 $3.00entry_MLB$4KMoonshot(AllDay) completed
# 2017-05-19 $5.00entry_MLB$5DoubleUp completed
# 2017-05-19 $5.00entry_MLB$5DoubleUp completed
# 2017-05-19 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-19 $1.00entry_MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-19 $0.25entry_MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-19 $1.00entry_MLB$500SoloShot(AllDay) completed
# 2017-05-19 $0.25entry_MLB$250QuarterArcade[Just$0.25!](AllDay) completed
# 2017-05-19 $10.00entry_MLB$10DoubleUp completed
# 2017-05-19 $2.00entry_MLB$2DoubleUp completed
# 2017-05-19 $1.00entry_MLB$10KSoloShot completed
# 2017-05-19 $2.00entry_MLB$4KFlare completed
# 2017-05-19 $0.25entry_MLB$4KQuarterArcade[Just$0.25!] completed
# 2017-05-19 $3.00entry_MLB$1.5KMoonshot(Turbo) completed
# 2017-05-19 $1.00entry_MLB$500SoloShot(Turbo) completed
# 2017-05-19 $0.25entry_MLB$300QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-19 $3.00entry_MLB$2KMoonshot(Turbo) completed
# 2017-05-19 $1.00entry_MLB$500SoloShot(Turbo) completed
# 2017-05-19 $0.25entry_MLB$400QuarterArcade[Just$0.25!](Turbo) completed
# 2017-05-19 $4.00entry_MLB$10KFour-Seamer(Night) completed
# 2017-05-19 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-19 $0.25entry_MLB$750QuarterArcade[Just$0.25!](Night) completed
# 2017-05-19 $4.00entry_MLB$4KFour-Seamer(LateNight) completed
# 2017-05-19 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-19 $0.25entry_MLB$500QuarterArcade[Just$0.25!](LateNight) completed
# 2017-05-20 $40.00entry_MLB$150KSaturdaySlugfest completed
# 2017-05-20 $4.00entry_MLB$65KFour-Seamer[20EntryMax] completed
# 2017-05-20 $33.00entry_MLB$110KFastball(Early) completed
# 2017-05-20 $4.00entry_MLB$50KFour-Seamer[20EntryMax](Early) completed
# 2017-05-20 $1.00entry_MLB$2.5KSoloShot(Early) completed
# 2017-05-20 $1.00entry_2DAYS:MLB$6SwingForTheFencesSUPERSat[150x](Early) completed
# 2017-05-20 $0.25entry_2DAYS:MLB$6SwingForTheFencesSUPERSat[100x](Early) completed
# 2017-05-20 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Early) completed
# 2017-05-20 $0.25entry_MLB$2.5KQuarterJukebox[Just$0.25!](Early) completed
# 2017-05-20 $1.00entry_2DAYS:MLB$6SwingForTheFencesSUPERSat[175x] completed
# 2017-05-20 $0.25entry_2DAYS:MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-20 $5.00entry_MLB$5DoubleUp completed
# 2017-05-20 $5.00entry_MLB$5DoubleUp completed
# 2017-05-20 $2.00entry_MLB$2DoubleUp completed
# 2017-05-20 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-20 $2.00entry_MLB$3KFlare completed
# 2017-05-20 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-05-20 $4.00entry_MLB$15KFour-Seamer(Night) completed
# 2017-05-20 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-20 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Night) completed
# 2017-05-21 $50.00entry_MLB$260KSundayNiftyFifty completed
# 2017-05-21 $4.00entry_MLB$80KFour-Seamer[20EntryMax] completed
# 2017-05-21 $333.00entry_MLB$150KPerfectGame completed
# 2017-05-21 $25.00entry_MLB$25DoubleUp completed
# 2017-05-21 $5.00entry_MLB$5DoubleUp completed
# 2017-05-21 $1.00entry_LASTSHOT:MLB$6SwingForTheFencesSUPERSat[200x] completed
# 2017-05-21 $0.25entry_LASTSHOT:MLB$6SwingForTheFencesSUPERSat[100x] completed
# 2017-05-21 $1.00entry_MLB$3.5MFantasyGolfMillionaireSUPERSatellite[10x] completed
# 2017-05-21 $2.00entry_MLB$3KFlare completed
# 2017-05-22 $6.00entry_MLB$300KSwingfortheFences[$50Kto1st] completed
# 2017-05-22 $55.00entry_MLB$300KFullCount[$50Kto1st] completed
# 2017-05-22 $444.00entry_MLB$225KGrandSlam completed
# 2017-05-22 $3.00entry_MLB$20KMoonshot[20EntryMax] completed
# 2017-05-22 $5.00entry_MLB$5DoubleUp completed
# 2017-05-22 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-22 $5.00entry_MLB$5DoubleUp completed
# 2017-05-22 $10.00entry_MLB$10DoubleUp completed
# 2017-05-22 $2.00entry_MLB$2DoubleUp completed
# 2017-05-22 $2.00entry_MLB$5KFlare completed
# 2017-05-22 $1.00entry_MLB$10KSoloShot completed
# 2017-05-22 $0.25entry_MLB$5KQuarterJukebox completed
# 2017-05-22 $4.00entry_MLB$7KFour-Seamer(Night) completed
# 2017-05-22 $3.00entry_MLB$3KMoonshot(Turbo) completed
# 2017-05-22 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-23 $8.00entry_MLB$250KMini8's[$50Kto1st] completed
# 2017-05-23 $88.00entry_MLB$300KMedium8's completed
# 2017-05-23 $4.00entry_MLB$40KFour-Seamer[20EntryMax] completed
# 2017-05-23 $5.00entry_MLB$5DoubleUp completed
# 2017-05-23 $5.00entry_MLB$5DoubleUp completed
# 2017-05-23 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-23 $10.00entry_MLB$10DoubleUp completed
# 2017-05-23 $2.00entry_MLB$2DoubleUp completed
# 2017-05-23 $1.00entry_MLB$10KSoloShot completed
# 2017-05-23 $2.00entry_MLB$4KFlare completed
# 2017-05-23 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-05-23 $4.00entry_MLB$3KFour-Seamer(Turbo) completed
# 2017-05-23 $0.25entry_MLB$250QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-05-23 $0.25entry_MLB$250QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-05-23 $4.00entry_MLB$2KFour-Seamer(Turbo) completed
# 2017-05-23 $0.25entry_MLB$200QuarterJukebox(Turbo) completed
# 2017-05-23 $4.00entry_MLB$10KFour-Seamer(Night) completed
# 2017-05-23 $1.00entry_MLB$1KSoloShot(Night) completed
# 2017-05-23 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Night) completed
# 2017-05-23 $4.00entry_MLB$4KFour-Seamer(LateNight) completed
# 2017-05-23 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-05-23 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](LateNight) completed
# 2017-05-24 $33.00entry_MLB$225KFastball completed
# 2017-05-24 $8.00entry_MLB$150KRallyCap completed
# 2017-05-25 $33.00entry_MLB$150KFastball completed
# 2017-05-25 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-25 $33.00entry_MLB$100KFastball(Early) completed
# 2017-05-25 $4.00entry_MLB$50KFour-Seamer[20EntryMax](Early) completed
# 2017-05-25 $5.00entry_MLB$5DoubleUp completed
# 2017-05-25 $5.00entry_MLB$5DoubleUp completed
# 2017-05-25 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-25 $2.00entry_MLB$2DoubleUp completed
# 2017-05-25 $2.00entry_MLB$3KFlare completed
# 2017-05-25 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-05-25 $4.00entry_MLB$2KFour-Seamer(AllDay) completed
# 2017-05-25 $0.25entry_MLB$250QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-05-25 $4.00entry_MLB$12KFour-Seamer(Night) completed
# 2017-05-25 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-25 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Night) completed
# 2017-05-25 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-25 $2.00entry_MLB$2.5KFlare(Early) completed
# 2017-05-25 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-25 $0.25entry_MLB$2.5KQuarterJukebox[Just$0.25!](Early) completed
# 2017-05-25 $3.00entry_MLB$2KMoonshot(Turbo) completed
# 2017-05-25 $0.25entry_MLB$200QuarterJukebox(Turbo) completed
# 2017-05-26 $55.00entry_MLB$300KFullCount[$50Kto1st] completed
# 2017-05-26 $555.00entry_MLB$400KWalk-OffHomeRun[$100Kto1st] completed
# 2017-05-26 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-26 $8.00entry_MLB$100KRallyCap completed
# 2017-05-26 $5.00entry_MLB$5DoubleUp completed
# 2017-05-26 $5.00entry_MLB$5DoubleUp completed
# 2017-05-26 $25.00entry_MLBGIANT$25DoubleUp completed
# 2017-05-26 $10.00entry_MLB$10DoubleUp completed
# 2017-05-26 $2.00entry_MLB$2DoubleUp completed
# 2017-05-26 $2.00entry_MLB$4KFlare completed
# 2017-05-26 $1.00entry_MLB$10KSoloShot completed
# 2017-05-26 $0.25entry_MLB$5KQuarterJukebox completed
# 2017-05-26 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-26 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-26 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-05-26 $3.00entry_MLB$4KMoonshot(Night) completed
# 2017-05-26 $1.00entry_MLB$750SoloShot(Night) completed
# 2017-05-26 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Night) completed
# 2017-05-26 $4.00entry_MLB$20KFour-Seamer(LateNight) completed
# 2017-05-26 $1.00entry_MLB$2KSoloShot(LateNight) completed
# 2017-05-26 $2.00entry_MLB$1KFlare(LateNight) completed
# 2017-05-26 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](LateNight) completed
# 2017-05-27 $40.00entry_MLB$125KSaturdaySlugfest[$15Kto1st](Early) completed
# 2017-05-27 $4.00entry_MLB$60KFour-Seamer[20EntryMax](Early) completed
# 2017-05-27 $40.00entry_MLB$150KSaturdaySlugfest completed
# 2017-05-27 $4.00entry_MLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-27 $2.00entry_MLB$1KFlare(Early) completed
# 2017-05-27 $2.00entry_MLB$2KFlare(Early) completed
# 2017-05-27 $1.00entry_MLB$3KSoloShot(Early) completed
# 2017-05-27 $1.00entry_MLB$5KSoloShot(Early) completed
# 2017-05-27 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Early) completed
# 2017-05-27 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-05-27 $3.00entry_MLB$2.5KMoonshot(AllDay) completed
# 2017-05-27 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-05-27 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-05-27 $3.00entry_MLB$3KMoonshot(Turbo) completed
# 2017-05-27 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-05-27 $0.25entry_MLB$500Jukebox[Just$0.25!](Turbo) completed
# 2017-05-27 $4.00entry_MLB$10KFour-Seamer[20EntryMax](Afternoon) completed
# 2017-05-27 $1.00entry_MLB$1.5KSoloShot(Afternoon) completed
# 2017-05-27 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Afternoon) completed
# 2017-05-27 $5.00entry_MLB$5DoubleUp completed
# 2017-05-27 $2.00entry_MLB$2DoubleUp completed
# 2017-05-27 $2.00entry_MLB$3KFlare completed
# 2017-05-27 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-27 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-05-27 $4.00entry_MLB$12KFour-Seamer[20EntryMax](Night) completed
# 2017-05-27 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-05-27 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Night) completed
# 2017-05-28 $50.00entry_MLB$250KSundayNiftyFifty completed
# 2017-05-28 $300.00entry_MLB$130KCurveball[$20Kto1st] completed
# 2017-05-28 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-05-28 $4.00entry_MLB$20KFour-Seamer(Afternoon) completed
# 2017-05-28 $33.00entry_MLB$15KFastball(Afternoon) completed
# 2017-05-28 $1.00entry_MLB$7.5KSoloShot completed
# 2017-05-28 $4.00entry_2DAYS:MLB$70FrozenRopeSUPERSat[100x] completed
# 2017-05-28 $1.00entry_2DAYS:MLB$70FrozenRopeSUPERSat[20x] completed
# 2017-05-28 $25.00entry_MLB$25DoubleUp completed
# 2017-05-28 $5.00entry_MLB$5DoubleUp completed
# 2017-05-28 $2.00entry_MLB$2DoubleUp completed
# 2017-05-28 $5.00entry_MLB$5DoubleUp completed
# 2017-05-28 $2.00entry_MLB$3KFlare completed
# 2017-05-28 $0.25entry_MLB$3KQuarterJukebox[Just$0.25!] completed
# 2017-05-28 $3.00entry_MLB$3KMoonshot(AllDay) completed
# 2017-05-28 $1.00entry_MLB$1KSoloShot(AllDay) completed
# 2017-05-28 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-05-28 $3.00entry_MLB$5KMoonshot(Turbo) completed
# 2017-05-28 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-28 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-05-28 $2.00entry_MLB$1KFlare(Afternoon) completed
# 2017-05-28 $1.00entry_MLB$1.5KSoloShot(Afternoon) completed
# 2017-05-28 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Afternoon) completed
# 2017-05-28 $3.00entry_MLB$4KMoonshot(Late) completed
# 2017-05-28 $1.00entry_MLB$1KSoloShot(Late) completed
# 2017-05-28 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Late) completed
# 2017-05-29 $33.00entry_MLB$50KFastball(Early) completed
# 2017-05-29 $4.00entry_MLB$30KMemorialDaySpecial[20EntryMax](Early) completed
# 2017-05-29 $4.00entry_MLB$100KMemorialDaySpecial[20EntryMax](Early) completed
# 2017-05-29 $4.00entry_LASTSHOT:MLB$70FrozenRopeSUPERSat[75x](Early) completed
# 2017-05-29 $1.00entry_LASTSHOT:MLB$70FrozenRopeSUPERSat[15x](Early) completed
# 2017-05-29 $33.00entry_MLB$110KFastball completed
# 2017-05-29 $4.00entry_DEVOURpresentsMLB$75KFour-Seamer[20EntryMax] completed
# 2017-05-29 $3.00entry_BostonRedSoxFirstPitchExperience(BigLeagueCallUp) completed
# 2017-05-29 $4.00entry_LASTSHOT:MLB$70FrozenRopeSUPERSat[75x] completed
# 2017-05-29 $1.00entry_LASTSHOT:MLB$70FrozenRopeSUPERSat[10x] completed
# 2017-05-29 $5.00entry_MLB$5DoubleUp completed
# 2017-05-29 $1.00entry_MLB$500SoloShot(AllDay) completed
# 2017-05-29 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-05-29 $1.00entry_MLB$4KSoloShot(Early) completed
# 2017-05-29 $0.25entry_MLB$2KQuarterJukebox[Just$0.25!](Early) completed
# 2017-05-29 $3.00entry_MLB$3KMoonshot(Turbo) completed
# 2017-05-29 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-05-29 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-05-29 $3.00entry_MLB$5KMoonshot(Afternoon) completed
# 2017-05-29 $1.00entry_MLB$1KSoloShot(Afternoon) completed
# ...
# 2017-06-21 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-06-21 $25.00entry_MLB$25DoubleUp completed
# 2017-06-21 $5.00entry_MLB$5DoubleUp completed
# 2017-06-21 $5.00entry_MLB$5DoubleUp completed
# 2017-06-21 $4.00entry_2DAYS:MLBSUPERSattoMLB$44MEGAPowerAlley[75x] completed
# 2017-06-21 $8.00entry_MLBSUPERSatellitetoThe$1.2M1776[2x] completed
# 2017-06-21 $1.00entry_2DAYS:MLB$44MEGAPowerAlleySUPERSatellite[10x](Early) completed
# 2017-06-21 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-06-21 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-06-21 $1.00entry_MLB$3KSoloShot(Early) completed
# 2017-06-21 $0.25entry_MLB$1.5KJukebox[Just$0.25!](Early) completed
# 2017-06-21 $2.00entry_MLB$2DoubleUp completed
# 2017-06-21 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-21 $1.00entry_2DAYS:MLBSUPERSattoMLB$44MEGAPowerAlley[30x] completed
# 2017-06-21 $2.00entry_MLB$3KFlare completed
# 2017-06-21 $1.00entry_MLB$7.5KSoloShot completed
# 2017-06-21 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-06-21 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-21 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-21 $0.25entry_MLB$200QuarterJukebox(AllDay) completed
# 2017-06-21 $4.00entry_MLB$5KFour-Seamer(Turbo) completed
# 2017-06-21 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-06-21 $0.25entry_MLB$500Jukebox[Just$0.25!](Turbo) completed
# 2017-06-21 $4.00entry_MLB$7KFour-Seamer[20EntryMax](Turbo) completed
# 2017-06-21 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-06-21 $0.25entry_MLB$500Jukebox[Just$0.25!](Turbo) completed
# 2017-06-21 $8.00entry_MLB$35KCrazy8's(Night) completed
# 2017-06-21 $33.00entry_MLB$12KFastball(Night) completed
# 2017-06-21 $4.00entry_MLB$10KFour-Seamer[20EntryMax](Night) completed
# 2017-06-21 $2.00entry_MLB$1KFlare(Night) completed
# 2017-06-21 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-06-21 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Night) completed
# 2017-06-22 $33.00entry_MLB$100KFastball(Early) completed
# 2017-06-22 $8.00entry_MLB$45KRallyCap(Early) completed
# 2017-06-22 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-06-22 $33.00entry_MLB$200KFastball completed
# 2017-06-22 $8.00entry_MLB$125KRallyCap completed
# 2017-06-22 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-06-22 $444.00entry_MLB$250KGrandSlam[$50Kto1st] completed
# 2017-06-22 $4.00entry_MLB$3KFour-Seamer(Turbo) completed
# 2017-06-22 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-06-22 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-22 $4.00entry_MLB$3KFour-Seamer(Turbo) completed
# 2017-06-22 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-06-22 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-22 $1.00entry_LASTSHOT:MLB$44MEGAPowerAlleySUPERSatellite[10x](Early) completed
# 2017-06-22 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-06-22 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-06-22 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-06-22 $1.00entry_MLB$3KSoloShot(Early) completed
# 2017-06-22 $0.25entry_MLB$2KQuarterJukebox[Just$0.25!](Early) completed
# 2017-06-22 $8.00entry_MLB$30KLateNightSpecial(Night) completed
# 2017-06-22 $33.00entry_MLB$12KFastball(Night) completed
# 2017-06-22 $4.00entry_MLB$7KFour-Seamer[20EntryMax](Night) completed
# 2017-06-22 $2.00entry_MLB$1KFlare(Night) completed
# 2017-06-22 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-06-22 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Night) completed
# 2017-06-22 $8.00entry_MLBSUPERSatellitetoThe$1.2M1776[2x] completed
# 2017-06-22 $4.00entry_LASTSHOT:MLBSUPERSattoMLB$44MEGAPowerAlley[50x] completed
# 2017-06-22 $1.00entry_LASTSHOT:MLBSUPERSattoMLB$44MEGAPowerAlley[20x] completed
# 2017-06-22 $3.00entry_WatchAstrosBattingPracticeExperience(BigLeagueCallUp) completed
# 2017-06-22 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-22 $25.00entry_MLB$25DoubleUp completed
# 2017-06-22 $5.00entry_MLB$5DoubleUp completed
# 2017-06-22 $5.00entry_MLB$5DoubleUp completed
# 2017-06-22 $2.00entry_MLB$2DoubleUp completed
# 2017-06-22 $1.00entry_MLB$7.5KSoloShot completed
# 2017-06-22 $2.00entry_MLB$3KFlare completed
# 2017-06-22 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-06-23 $44.00entry_MLB$350KMEGAPowerAlley completed
# 2017-06-23 $8.00entry_MLB$140KRallyCap completed
# 2017-06-23 $4.00entry_MLB$100KFour-Seamer[20EntryMax] completed
# 2017-06-23 $444.00entry_MLB$400KGrandSlam[$100Kto1st!] completed
# 2017-06-23 $3.40entry_MLB$34KPapi completed
# 2017-06-23 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-06-23 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-23 $3.00entry_MetsFirstPitchExperience(BigLeagueCallUp) completed
# 2017-06-23 $25.00entry_MLB$25DoubleUp completed
# 2017-06-23 $5.00entry_MLB$5DoubleUp completed
# 2017-06-23 $5.00entry_MLB$5DoubleUp completed
# 2017-06-23 $10.00entry_MLB$10DoubleUp completed
# 2017-06-23 $2.00entry_MLB$2DoubleUp completed
# 2017-06-23 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-23 $2.00entry_MLB$3KFlare completed
# 2017-06-23 $1.00entry_MLB$10KSoloShot completed
# 2017-06-23 $0.25entry_MLB$4KQuarterJukebox[Just$0.25!] completed
# 2017-06-23 $4.00entry_MLB$3KFour-Seamer(Turbo) completed
# 2017-06-23 $1.00entry_MLB$500SoloShot(Turbo) completed
# 2017-06-23 $0.25entry_MLB$350QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-23 $8.00entry_MLB$20KRallyCap(Night) completed
# 2017-06-23 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Night) completed
# 2017-06-23 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-06-23 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Night) completed
# 2017-06-23 $4.00entry_MLB$5KFour-Seamer[20EntryMax](LateNight) completed
# 2017-06-23 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-06-23 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](LateNight) completed
# 2017-06-23 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-23 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-24 $40.00entry_MLB$150KSaturdaySlugfest(Early) completed
# 2017-06-24 $4.00entry_MLB$50KFour-Seamer[20EntryMax](Early) completed
# 2017-06-24 $8.00entry_MLB$50KRallyCap(Early) completed
# 2017-06-24 $40.00entry_MLB$160KSaturdaySlugfest completed
# 2017-06-24 $8.00entry_MLB$60KRallyCap completed
# 2017-06-24 $4.00entry_MLB$50KFour-Seamer[20EntryMax] completed
# 2017-06-24 $3.00entry_DodgersFirstPitchExperience(BigLeagueCallUp) completed
# 2017-06-24 $3.00entry_MLBAll-StarGameTriptoMiami completed
# 2017-06-24 $4.00entry_MLBSatellitetoThe$1.2M1776(Early) completed
# 2017-06-24 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-06-24 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x](Early) completed
# 2017-06-24 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x](Early) completed
# 2017-06-24 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-06-24 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-06-24 $1.00entry_MLB$5KSoloShot(Early) completed
# 2017-06-24 $0.25entry_MLB$2KQuarterJukebox[Just$0.25!](Early) completed
# 2017-06-24 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-24 $5.00entry_MLB$5DoubleUp completed
# 2017-06-24 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-24 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-24 $2.00entry_MLB$2DoubleUp completed
# 2017-06-24 $2.00entry_MLB$1.5KFlare completed
# 2017-06-24 $1.00entry_MLB$5KSoloShot completed
# 2017-06-24 $0.25entry_MLB$2KQuarterJukebox[Just$0.25!] completed
# 2017-06-24 $3.00entry_MLB$2.5KMoonshot(AllDay) completed
# 2017-06-24 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-06-24 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-06-24 $8.00entry_MLB$10KRallyCap(Afternoon) completed
# 2017-06-24 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Afternoon) completed
# 2017-06-24 $1.00entry_MLB$1KSoloShot(Afternoon) completed
# 2017-06-24 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Afternoon) completed
# 2017-06-24 $8.00entry_MLB$30KLateNightSpecial(Night) completed
# 2017-06-24 $33.00entry_MLB$15KFastball(Night) completed
# 2017-06-24 $4.00entry_MLB$10KFour-Seamer[20EntryMax](Night) completed
# 2017-06-24 $2.00entry_MLB$1KFlare(Night) completed
# 2017-06-24 $1.00entry_MLB$2.5KSoloShot(Night) completed
# 2017-06-24 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Night) completed
# 2017-06-25 $50.00entry_MLB$325KSundayNiftyFifty[$50Kto1st] completed
# 2017-06-25 $8.00entry_MLB$100KRallyCap completed
# 2017-06-25 $333.00entry_MLB$140KPerfectGame completed
# 2017-06-25 $4.00entry_MLB$60KFour-Seamer[20EntryMax] completed
# 2017-06-25 $5.00entry_MLB$5DoubleUp completed
# 2017-06-25 $5.00entry_MLB$5DoubleUp completed
# 2017-06-25 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-25 $2.00entry_MLB$2DoubleUp completed
# 2017-06-25 $2.00entry_MLB$3KFlare completed
# 2017-06-25 $1.00entry_MLB$6KSoloShot completed
# 2017-06-25 $0.25entry_MLB$2KQuarterJukebox[Just$0.25!] completed
# 2017-06-25 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-25 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-25 $4.00entry_MLB$3KFour-Seamer(AllDay) completed
# 2017-06-25 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-06-25 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-06-25 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Turbo) completed
# 2017-06-25 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-06-25 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-25 $8.00entry_MLB$20KRallyCap(Afternoon) completed
# 2017-06-25 $33.00entry_MLB$15KFastball(Afternoon) completed
# 2017-06-25 $4.00entry_MLB$12KFour-Seamer[20EntryMax](Afternoon) completed
# 2017-06-25 $8.00entry_MLBSUPERSatellitetoThe$1.2M1776[2x](Afternoon) completed
# 2017-06-25 $2.00entry_MLB$1KFlare(Afternoon) completed
# 2017-06-25 $1.00entry_MLB$2KSoloShot(Afternoon) completed
# 2017-06-25 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Afternoon) completed
# 2017-06-25 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Night) completed
# 2017-06-25 $1.00entry_MLB$1KSoloShot(Night) completed
# 2017-06-25 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Night) completed
# 2017-06-26 $6.00entry_MLB$300KSwingfortheFences[$50Kto1st] completed
# 2017-06-26 $55.00entry_MLB$250KFullCount completed
# 2017-06-26 $8.00entry_MLB$40KRallyCap(Early) completed
# 2017-06-26 $444.00entry_MLB$250KGrandSlam[$50Kto1st] completed
# 2017-06-26 $1.00entry_MLB$30KWelcomeParty completed
# 2017-06-26 $4.00entry_MLB$20KFour-Seamer[20EntryMax](Early) completed
# 2017-06-26 $3.00entry_PadresFirstPitchExperience(BigLeagueCallUp) completed
# 2017-06-26 $3.00entry_MLBAll-StarGameTriptoMiami completed
# 2017-06-26 $25.00entry_MLB$25DoubleUp completed
# 2017-06-26 $5.00entry_MLB$5DoubleUp completed
# 2017-06-26 $5.00entry_MLB$5DoubleUp completed
# 2017-06-26 $2.00entry_MLB$1.5KFlare(Early) completed
# 2017-06-26 $1.00entry_MLB$2KSoloShot(Early) completed
# 2017-06-26 $0.25entry_MLB$1.5KQuarterJukebox[Just$0.25!](Early) completed
# 2017-06-26 $4.00entry_MLB$3KFour-Seamer(AllDay) completed
# 2017-06-26 $1.00entry_MLB$750SoloShot(AllDay) completed
# 2017-06-26 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](AllDay) completed
# 2017-06-26 $8.00entry_MLBSUPERSatellitetoThe$1.2M1776[2x] completed
# 2017-06-26 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-26 $2.00entry_MLB$2DoubleUp completed
# 2017-06-26 $2.00entry_MLB$4KFlare completed
# 2017-06-26 $0.25entry_MLB$5KQuarterJukebox completed
# 2017-06-26 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-26 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-26 $4.00entry_MLB$7KFour-Seamer[20EntryMax](Night) completed
# 2017-06-26 $1.00entry_MLB$1KSoloShot(Night) completed
# 2017-06-26 $0.25entry_MLB$500QuarterJukebox[Just$0.25!](Night) completed
# 2017-06-26 $8.00entry_MLB$30KRallyCap(LateNight) completed
# 2017-06-26 $33.00entry_MLB$15KFastball(LateNight) completed
# 2017-06-26 $4.00entry_MLB$8KFour-Seamer[20EntryMax](LateNight) completed
# 2017-06-26 $2.00entry_MLB$1KFlare(LateNight) completed
# 2017-06-26 $1.00entry_MLB$2.5KSoloShot(LateNight) completed
# 2017-06-26 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](LateNight) completed
# 2017-06-27 $444.00entry_MLB$500KBatFlip[$100Kto1st] completed
# 2017-06-27 $44.00entry_MLB$350KMediumBatFlip[$50Kto1st] completed
# 2017-06-27 $4.00entry_MLB$200KMiniBatFlip[20EntryMax] completed
# 2017-06-27 $8.00entry_MLB$80KRallyCap completed
# 2017-06-27 $8.00entry_MLBSUPERSatellitetoThe$1.2M1776[2x] completed
# 2017-06-27 $3.00entry_DodgersMeetandGreetExperience(BigLeagueCallUp) completed
# 2017-06-27 $3.00entry_MLBAll-StarGameTriptoMiami completed
# 2017-06-27 $4.00entry_MLBSatellitetoThe$1.2M1776 completed
# 2017-06-27 $25.00entry_MLB$25DoubleUp completed
# 2017-06-27 $5.00entry_MLB$5DoubleUp completed
# 2017-06-27 $5.00entry_MLB$5DoubleUp completed
# 2017-06-27 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-27 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-27 $10.00entry_MLB$10DoubleUp completed
# 2017-06-27 $2.00entry_MLB$2DoubleUp completed
# 2017-06-27 $3.00entry_MLB$3KMoonshot completed
# 2017-06-27 $2.00entry_MLB$4KFlare completed
# 2017-06-27 $1.00entry_MLB$10KSoloShot completed
# 2017-06-27 $0.25entry_MLB$5KQuarterJukebox completed
# 2017-06-27 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Turbo) completed
# 2017-06-27 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-06-27 $0.25entry_MLB$500Jukebox[Just$0.25!](Turbo) completed
# 2017-06-27 $8.00entry_MLB$25KRallyCap(Night) completed
# 2017-06-27 $33.00entry_MLB$15KFastball(Night) completed
# 2017-06-27 $4.00entry_MLB$5KFour-Seamer[20EntryMax](Night) completed
# 2017-06-27 $1.00entry_MLB$2KSoloShot(Night) completed
# 2017-06-27 $0.25entry_MLB$1KQuarterJukebox[Just$0.25!](Night) completed
# 2017-06-27 $8.00entry_MLB$10KRallyCap(LateNight) completed
# 2017-06-27 $4.00entry_MLB$3KFour-Seamer(LateNight) completed
# 2017-06-27 $1.00entry_MLB$1KSoloShot(LateNight) completed
# 2017-06-27 $0.25entry_MLB$500Jukebox[Just$0.25!](LateNight) completed
# 2017-06-29 $444.00entry_MLB$250KGrandSlam[$50Kto1st] completed
# 2017-06-29 $33.00entry_SummerBash$200KFastball completed
# 2017-06-29 $8.00entry_MLB$115KRallyCap completed
# 2017-06-29 $4.00entry_MLB$90KFour-Seamer[20EntryMax] completed
# 2017-06-29 $33.00entry_MLB$80KFastball(Early) completed
# 2017-06-29 $4.00entry_MLB$40KFour-Seamer[20EntryMax](Early) completed
# 2017-06-29 $8.00entry_MLB$40KRallyCap(Early) completed
# 2017-06-29 $8.00entry_LASTSHOT:MLBSUPERSatellitetoThe$1.2M1776[2x] completed
# 2017-06-29 $5.00entry_MLB$5DoubleUp(Early) completed
# 2017-06-29 $2.00entry_MLB$2DoubleUp(Early) completed
# 2017-06-29 $2.00entry_MLB$1KFlare(Early) completed
# 2017-06-29 $1.00entry_MLB$3KSoloShot(Early) completed
# 2017-06-29 $0.25entry_MLB$1.5KJukebox[Just$0.25!](Early) completed
# 2017-06-29 $0.25entry_MLB$200Jukebox(AllDay) completed
# 2017-06-29 $4.00entry_MLB$3KFour-Seamer(Turbo) completed
# 2017-06-29 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-06-29 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-29 $4.00entry_MLB$4KFour-Seamer[20EntryMax](Turbo) completed
# 2017-06-29 $1.00entry_MLB$750SoloShot(Turbo) completed
# 2017-06-29 $0.25entry_MLB$400QuarterJukebox[Just$0.25!](Turbo) completed
# 2017-06-29 $4.00entry_MLB$4KFour-Seamer[20EntryMax](Turbo) completed
# 2017-06-29 $1.00entry_MLB$1KSoloShot(Turbo) completed
# 2017-06-29 $0.25entry_MLB$500Jukebox[Just$0.25!](Turbo) completed
# 2017-06-29 $8.00entry_MLB$20KRallyCap(Night) completed
# 2017-06-29 $4.00entry_MLB$4KFour-Seamer[20EntryMax](Night) completed
# 2017-06-29 $1.00entry_MLB$1.5KSoloShot(Night) completed
# 2017-06-29 $0.25entry_MLB$750QuarterJukebox[Just$0.25!](Night) completed
# 2017-06-29 $4.00entry_LASTSHOT:MLBSatellitetoThe$1.2M1776 completed
# 2017-06-29 $5.00entry_MLB$5DoubleUp completed
# 2017-06-29 $5.00entry_MLB$5DoubleUp completed
# 2017-06-29 $2.00entry_MLB$2DoubleUp completed
# 2017-06-29 $1.00entry_MLBSUPERSattoMLBSwingfortheFences[100x] completed
# 2017-06-29 $0.25entry_MLBSUPERSattoMLBSwingfortheFences[50x] completed
# 2017-06-29 $3.00entry_MLB$3KMoonshot completed
# 2017-06-29 $3.00entry_MLB$2KMoonshot completed
# 2017-06-29 $2.00entry_MLB$2.5KFlare completed
# 2017-06-29 $1.00entry_MLB$7.5KSoloShot completed
# 2017-06-29 $0.25entry_MLB$3KQuarterJukebox[Just$0.25!] completed
